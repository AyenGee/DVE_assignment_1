# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 


df = pd.read_csv("logbook_assignment1.csv")
print(df.shape)
df.dtypes
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23996\1044866353.py:6: DtypeWarning: Columns (0: gallons, 1: mpg) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("logbook_assignment1.csv")
# (1174870, 9)
# date_fueled           str
# date_captured         str
# odometer              str
# gallons            object
# cost_per_gallon       str
# total_spent           str
# mpg                object
# miles                 str
# user_url              str
# dtype: object

# %%
parsed_dates = pd.to_datetime(df["date_fueled"], errors="coerce", format="mixed")
pct_invalid = parsed_dates.isna().mean() * 100
print(f"{pct_invalid:.2f}% of date_fueled entries are not valid dates")
